# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
from matplotlib.ticker import LinearLocator
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from PIL import Image

# %%
data =  np.load("./MNIST_data/data1.npy")

fig = plt.figure(figsize = (8,8))
for i in range(25):
    im = data[i]
    ax = fig.add_subplot(5, 5, i+1)
    ax.imshow(im, cmap = 'gray')
    ax.axis('off')
    ax.axis('equal')
    
plt.tight_layout()
plt.show()

data.shape
# Out:
# (1000, 12, 12)

# %%
data =  np.load("./MNIST_data/data3.npy")

fig = plt.figure(figsize = (8,8))
for i in range(25):
    im = data[i]
    ax = fig.add_subplot(5, 5, i+1)
    ax.imshow(im, cmap = 'gray')
    ax.axis('off')
    ax.axis('equal')
    
plt.tight_layout()
plt.show()

data.shape
# Out:
# (1000, 12, 12)

# %%
import numpy as np

data1 = np.load("./MNIST_data/data1.npy")
data2 = np.load("./MNIST_data/data2.npy")
data3 = np.load("./MNIST_data/data3.npy")
data4 = np.load("./MNIST_data/data4.npy")

data = np.concatenate([data1, data2, data3, data4], axis=0)
labels = np.concatenate([
    np.ones(len(data1)) * 1,
    np.ones(len(data2)) * 2,
    np.ones(len(data3)) * 3,
    np.ones(len(data4)) * 4,
], axis=0)

idx = np.arange(len(data))
np.random.shuffle(idx)

data = data[idx]
labels = labels[idx]

test = np.load("./MNIST_data/test_data.npy")
labels = np.load("./MNIST_data/test_labels.npy")


fig = plt.figure(figsize = (8,8))
for i in range(25):
    im = test[i]
    ax = fig.add_subplot(5, 5, i+1)
    ax.imshow(im, cmap = 'gray')
    ax.axis('off')
    ax.axis('equal')
    
plt.tight_layout()
plt.show()

test.shape
# Out:
# (4000, 12, 12)
